# %% [markdown]
# # 1. 패키지 설치

# %%
pip install stable_baselines3

# %%
import numpy as np
import gymnasium
from gymnasium import Env
from stable_baselines3 import PPO
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete
import os

# %% [markdown]
# # 2. 환경 정의

# %%
n_jobs=5
n_machines=3
processing_times =[]
prosses_num=5
for i in range(prosses_num):
  processing_times.append(np.random.randint(1, 50, size=n_jobs).tolist())

# %%
class JobSchedulingEnv(Env):
    def __init__(self, n_jobs, n_machines):
        self.n_jobs = n_jobs
        self.n_machines = n_machines
        # Observation space: Each job's processing time
        #빈칸을 채우세요
        # Randomly initialize processing times for jobs
        self.processing_times = processing_times[0]#np.random.randint(1, 50, size=n_jobs)
        # Action space: Assign each job to a machine
        self.action_space = MultiDiscrete([n_machines] * n_jobs)
        self.current_time=1
        self.machine_times=np.zeros(self.n_machines)

    def reset(self,seed=None):
        #빈칸을 채우세요
        return self.processing_times,{}

    def step(self, action):
        # action에 의해 할당된 작업 및 각 기계의 스케줄을 생성
        for job, machine in enumerate(action):
            self.machine_times[machine] += self.processing_times[job]

        #모든 기계 중 작업이 가장 늦게 끝나는 기계의 총 작업 시간
        makespan = np.max(self.machine_times)

        # Reward를 작업 시간을 최소화하도록 설정 (makespan: 작업 시작부터 끝까지 경과된 시간의 길이)
        #빈칸을 채우세요

        # Check if the episode is done
        if self.current_time==prosses_num:
            #빈칸을 채우세요
            self.processing_times=np.zeros(n_machines).tolist()
        else:
            #빈칸을 채우세요
            self.processing_times=processing_times[self.current_time]#np.random.randint(1, 50, size=self.n_jobs)
        # Additional information
        info = {}
        truncated=False
        self.current_time+=1
        next_state=self.processing_times

        return next_state, reward, done, truncated,info

    def render(self, mode='human'):
        pass

# %%
import plotly.express as px
import pandas as pd
from datetime import datetime, timedelta

def render_schedule(schedule, job_times, n_machines):
    """
    schedule: list of machine assignments for each job
    job_times: list of processing times for each job
    n_machines: number of machines
    """
    start_time = datetime(2024, 8, 29, 0, 0, 0)
    # Create a list of dictionaries to hold the job schedule data
    data = []
    machine_end_times = [start_time] * n_machines  # 각 기계의 종료 시간을 초기화
    for i in range(len(schedule)):
        for job_id, machine_id in enumerate(schedule[i]):
            start_time = machine_end_times[machine_id]
            end_time = start_time + timedelta(seconds=job_times[i][job_id])
            data.append(dict(Task=f"Machine {machine_id + 1}",
                            Start=start_time,
                            Finish=end_time,
                            Job=f"Job {job_id + 1}",Index=i))
            machine_end_times[machine_id] = end_time  # 업데이트 기계의 종료 시간
    # Convert to DataFrame
    df = pd.DataFrame(data)
    # Plot the Gantt chart
    fig = px.timeline(df, x_start="Start", x_end="Finish", y="Job", color="Task", title="Gantt Chart",hover_data=["Index"])
    #print([i for i in range(len(job_times[0]))])
    fig.update_yaxes(categoryorder="category ascending")#categoryorder="array", categoryarray=[i+1 for i in range(len(job_times[0]))])
    #fig.update_yaxes()
    fig.show()

# %% [markdown]
# # 3. 환경 테스트

# %%
# Test the environment
env = JobSchedulingEnv(n_jobs=n_jobs, n_machines=n_machines)
obs,_ = env.reset()
done = False
schedule=[]
job_times=[]
score=0
while not done:
    #env.render()
    action = env.action_space.sample()
    obs, reward,done,_, info = env.step(action)
    schedule.append(action.tolist())
    job_times.append(obs)
    score+=reward
# Example usage
print(processing_times,"job_times")
print(schedule,"schedule")
render_schedule(schedule, processing_times, n_machines)
# Out:
# [[22, 31, 14, 18, 4], [10, 37, 19, 36, 29], [41, 49, 31, 22, 27], [4, 38, 19, 32, 9], [9, 42, 16, 12, 39]] job_times
# [[0, 2, 1, 1, 2], [2, 0, 2, 0, 1], [2, 2, 1, 2, 1], [2, 0, 1, 2, 1], [1, 2, 1, 2, 2]] schedule
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c7754d86-2c5a-4aec-aad5-3c52600069fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7754d86-2c5a-4aec-aad5-3c52600069fc")) {                    Plotly.newPlot(                        "c7754d86-2c5a-4aec-aad5-3c52600069fc",                        [{"alignmentgroup":"True","base":["2024-06-28T00:00:00","2024-06-28T00:00:22","2024-06-28T00:00:59","2024-06-28T00:01:35"],"customdata":[[0],[1],[1],[3]],"hovertemplate":"Task=Machine 1\u003cbr\u003eStart=%{base}\u003cbr\u003eFinish=%{x}\u003cbr\u003eJob=%{y}\u003cbr\u003eIndex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine 1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Machine 1","offsetgroup":"Machine 1","orientation":"h","showlegend":true,"textposition":"auto","x":[22000.0,37000.0,36000.0,38000.0],"xaxis":"x","y":["Job 1","Job 2","Job 4","Job 2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-06-28T00:00:00","2024-06-28T00:00:31","2024-06-28T00:00:35","2024-06-28T00:00:45","2024-06-28T00:01:04","2024-06-28T00:01:45","2024-06-28T00:02:34","2024-06-28T00:02:56","2024-06-28T00:03:00","2024-06-28T00:03:32","2024-06-28T00:04:14","2024-06-28T00:04:26"],"customdata":[[0],[0],[1],[1],[2],[2],[2],[3],[3],[4],[4],[4]],"hovertemplate":"Task=Machine 3\u003cbr\u003eStart=%{base}\u003cbr\u003eFinish=%{x}\u003cbr\u003eJob=%{y}\u003cbr\u003eIndex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine 3","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machine 3","offsetgroup":"Machine 3","orientation":"h","showlegend":true,"textposition":"auto","x":[31000.0,4000.0,10000.0,19000.0,41000.0,49000.0,22000.0,4000.0,32000.0,42000.0,12000.0,39000.0],"xaxis":"x","y":["Job 2","Job 5","Job 1","Job 3","Job 1","Job 2","Job 4","Job 1","Job 4","Job 2","Job 4","Job 5"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-06-28T00:00:00","2024-06-28T00:00:14","2024-06-28T00:00:32","2024-06-28T00:01:01","2024-06-28T00:01:32","2024-06-28T00:01:59","2024-06-28T00:02:18","2024-06-28T00:02:27","2024-06-28T00:02:36"],"customdata":[[0],[0],[1],[2],[2],[3],[3],[4],[4]],"hovertemplate":"Task=Machine 2\u003cbr\u003eStart=%{base}\u003cbr\u003eFinish=%{x}\u003cbr\u003eJob=%{y}\u003cbr\u003eIndex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine 2","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Machine 2","offsetgroup":"Machine 2","orientation":"h","showlegend":true,"textposition":"auto","x":[14000.0,18000.0,29000.0,31000.0,27000.0,19000.0,9000.0,9000.0,16000.0],"xaxis":"x","y":["Job 3","Job 4","Job 5","Job 3","Job 5","Job 3","Job 5","Job 1","Job 3"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...

# %% [markdown]
# # 4. 강화학습 모델 정의 및 학습

# %%
env=JobSchedulingEnv(n_jobs=n_jobs,n_machines=n_machines)
log_path = os.path.join('Training', 'Logs','PPO')

# %%
model = PPO('MlpPolicy', env, verbose=1,tensorboard_log=log_path)
#model = PPO('MlpPolicy', env, verbose = 1)
# model = PPO('MlpPolicy', env, verbose = 1,tensorboard_log=log_path,nsteps=1000,batch_size=100)
model.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training/Logs/PPO/PPO_11
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5        |
# |    ep_rew_mean     | -862     |
# | time/              |          |
# |    fps             | 473      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -861        |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007303755 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.49       |
# |    explained_variance   | -0.00269    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 3.46e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -837         |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0072548934 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.48        |
# |    explained_variance   | 0.00021      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+05     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00764     |
# |    value_loss           | 3.37e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -867        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010134615 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.000104    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 3.37e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -853        |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009075761 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 6.28e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 3.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -838        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 6           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006797574 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 4.26e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 3.18e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -848        |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 7           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013076041 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.46       |
# |    explained_variance   | 3.06e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 3.14e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -851        |
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 8           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009391958 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 2.34e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 3.06e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -848         |
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 9            |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0089867925 |
# |    clip_fraction        | 0.0732       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.41        |
# |    explained_variance   | 1.76e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.54e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00982     |
# |    value_loss           | 3.04e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -865        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 10          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010899166 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 1.34e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 2.99e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -846        |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 11          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010045307 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 9.54e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56e+05    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 3e+05       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -854        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 12          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010835411 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 6.44e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+05     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 2.8e+05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | -843       |
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 13         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01208358 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.4       |
# |    explained_variance   | 4.71e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.49e+05   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0119    |
# |    value_loss           | 2.79e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -847        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 14          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008354163 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 4.11e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 2.76e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -852        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 15          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010065805 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 3.4e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 2.68e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -829        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 16          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008221776 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 2.66e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -854        |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 17          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008162584 |
# |    clip_fraction        | 0.0678      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 2.38e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+05     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 2.53e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -841        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 18          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009632634 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 2.21e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 2.54e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | -848       |
# | time/                   |            |
# |    fps                  | 302        |
# |    iterations           | 19         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00954027 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.33      |
# |    explained_variance   | 1.85e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.22e+05   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 2.49e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -846        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 20          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009936016 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 1.43e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+05     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 2.45e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -851        |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 21          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010533942 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 1.19e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+05     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 2.43e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -836        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 22          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007415998 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 1.43e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+05     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 2.38e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -854        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 23          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011995606 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.26       |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 2.22e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -827        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 24          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008487677 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.25       |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+05    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 2.2e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -852         |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 25           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0097538065 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.22        |
# |    explained_variance   | 8.34e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 2.15e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -825        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 26          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010564867 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | 8.34e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.13e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00989    |
# |    value_loss           | 2.1e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -837        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 27          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010022411 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.18       |
# |    explained_variance   | 6.56e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.86e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.98e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -837        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 28          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007133299 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 7.15e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 2.03e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -829        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 29          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010504033 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.11       |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.65e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 1.96e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -839        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 30          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008698751 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 5.96e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.19e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 1.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -825        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 31          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010763649 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.29e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 1.87e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -815        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 32          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011148009 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.63e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 1.79e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -846         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 33           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0093853455 |
# |    clip_fraction        | 0.0933       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.89        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.6e+04      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0134      |
# |    value_loss           | 1.71e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -813        |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 34          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009674301 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.75e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00914    |
# |    value_loss           | 1.64e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -837        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 35          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011128139 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.71e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 1.55e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -813        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 36          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013981817 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.9e+04     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 1.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -828        |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 37          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008189512 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.95e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 1.51e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -820        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 38          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008474162 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.66       |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.77e+04    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 1.49e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -794        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 39          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008990817 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.58e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 1.46e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -819        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 40          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012257769 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.47e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 1.36e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -795        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 41          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011664534 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 1.31e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -815        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 42          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010102851 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.76e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 1.2e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -801         |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 43           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0101921875 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.35        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.43e+04     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 1.21e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | -789       |
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 44         |
# |    time_elapsed         | 309        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01271878 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 2.38e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.7e+04    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 1.14e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -781        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 45          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013318315 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.59e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 1.12e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -775        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 46          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009200374 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.21e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00979    |
# |    value_loss           | 1.05e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -779        |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 47          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010802852 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.89e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.04e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -781        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 48          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011091972 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55e+04    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 9.63e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -766        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 49          |
# |    time_elapsed         | 345         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010989173 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.52e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0084     |
# |    value_loss           | 9.56e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -788        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 50          |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011534024 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.95e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 9.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -775        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 51          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.014600009 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.39e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 9.06e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -778        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 52          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009366289 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.25e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0075     |
# |    value_loss           | 8.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -769        |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 53          |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.018410314 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.42e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 8.04e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | -759       |
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 54         |
# |    time_elapsed         | 381        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01217068 |
# |    clip_fraction        | 0.0967     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.65e+04   |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.012     |
# |    value_loss           | 7.78e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | -777       |
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 55         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.01292057 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.36      |
# |    explained_variance   | 2.38e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.59e+04   |
# |    n_updates            | 540        |
# ...
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -669         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 81           |
# |    time_elapsed         | 577          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0077305716 |
# |    clip_fraction        | 0.0989       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.86e+03     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 7.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -661        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 82          |
# |    time_elapsed         | 584         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.017327346 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 6.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -663        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 83          |
# |    time_elapsed         | 591         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.009427479 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+03    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 5.76e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -669         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 84           |
# |    time_elapsed         | 598          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0077900803 |
# |    clip_fraction        | 0.0722       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.74e+03     |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00628     |
# |    value_loss           | 5.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -662        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 85          |
# |    time_elapsed         | 605         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.007900641 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59e+03    |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 4.76e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -663        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 86          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.012597519 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 3.76e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -658         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 87           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0059108785 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+03     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00808     |
# |    value_loss           | 3.55e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -652        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 88          |
# |    time_elapsed         | 626         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.031832457 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41e+03    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 3.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -653        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 89          |
# |    time_elapsed         | 633         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.004821036 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 837         |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -656        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 90          |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.026287122 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 922         |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 1.83e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -653        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 91          |
# |    time_elapsed         | 647         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.006438354 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 825         |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 1.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -642        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 92          |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.010055748 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 503         |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -646        |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 93          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.002202545 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 404         |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 941         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -641         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 94           |
# |    time_elapsed         | 668          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0029015446 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.415       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 157          |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.00985     |
# |    value_loss           | 753          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5          |
# |    ep_rew_mean          | -640       |
# | time/                   |            |
# |    fps                  | 287        |
# |    iterations           | 95         |
# |    time_elapsed         | 675        |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.00444181 |
# |    clip_fraction        | 0.0593     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.374     |
# |    explained_variance   | 0.981      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 409        |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.0162    |
# |    value_loss           | 493        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5           |
# |    ep_rew_mean          | -638        |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 96          |
# |    time_elapsed         | 682         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004668668 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.34       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00961    |
# |    value_loss           | 336         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -640         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 97           |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0051235566 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.288       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.1         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00895     |
# |    value_loss           | 265          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5            |
# |    ep_rew_mean          | -637         |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 98           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0021384468 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 159          |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.00912     |
# |    value_loss           | 254          |
# ------------------------------------------

# %% [markdown]
# # 5.학습 과정 시각화

# %%
# %load_ext tensorboard
#%reload_ext tensorboard
training_log_path = os.path.join(log_path)
# training_log_path = os.path.join(log_path,'PPO_2')
# %tensorboard --logdir={training_log_path} --port=6009

# %% [markdown]
# # 6.학습된 강화학습 모델 평가

# %%
# Test the environment
observation,_ = env.reset()
done = False
schedule=[]
job_times=[]
score=0
while not done:
    #env.render()
    action=model.predict(observation)[0]
    #action = env.action_space.sample() #
    obs, reward,done,_, info = env.step(action)
    schedule.append(action.tolist())
    #job_times.append(obs))
    score+=reward
# Example usage
print(processing_times,"job_times")
print(schedule,"schedule")
render_schedule(schedule, processing_times, n_machines)
# Out:
# [[22, 31, 14, 18, 4], [10, 37, 19, 36, 29], [41, 49, 31, 22, 27], [4, 38, 19, 32, 9], [9, 42, 16, 12, 39]] job_times
# [[2, 1, 0, 0, 2], [2, 1, 0, 0, 2], [2, 1, 0, 0, 1], [2, 1, 0, 0, 2], [2, 1, 0, 0, 2]] schedule
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d27ef0a0-7a33-4440-8932-f49e51da8981" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d27ef0a0-7a33-4440-8932-f49e51da8981")) {                    Plotly.newPlot(                        "d27ef0a0-7a33-4440-8932-f49e51da8981",                        [{"alignmentgroup":"True","base":["2024-06-28T00:00:00","2024-06-28T00:00:22","2024-06-28T00:00:26","2024-06-28T00:00:36","2024-06-28T00:01:05","2024-06-28T00:01:46","2024-06-28T00:01:50","2024-06-28T00:01:59","2024-06-28T00:02:08"],"customdata":[[0],[0],[1],[1],[2],[3],[3],[4],[4]],"hovertemplate":"Task=Machine 3\u003cbr\u003eStart=%{base}\u003cbr\u003eFinish=%{x}\u003cbr\u003eJob=%{y}\u003cbr\u003eIndex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine 3","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Machine 3","offsetgroup":"Machine 3","orientation":"h","showlegend":true,"textposition":"auto","x":[22000.0,4000.0,10000.0,29000.0,41000.0,4000.0,9000.0,9000.0,39000.0],"xaxis":"x","y":["Job 1","Job 5","Job 1","Job 5","Job 1","Job 1","Job 5","Job 1","Job 5"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-06-28T00:00:00","2024-06-28T00:00:31","2024-06-28T00:01:08","2024-06-28T00:01:57","2024-06-28T00:02:24","2024-06-28T00:03:02"],"customdata":[[0],[1],[2],[2],[3],[4]],"hovertemplate":"Task=Machine 2\u003cbr\u003eStart=%{base}\u003cbr\u003eFinish=%{x}\u003cbr\u003eJob=%{y}\u003cbr\u003eIndex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine 2","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Machine 2","offsetgroup":"Machine 2","orientation":"h","showlegend":true,"textposition":"auto","x":[31000.0,37000.0,49000.0,27000.0,38000.0,42000.0],"xaxis":"x","y":["Job 2","Job 2","Job 2","Job 5","Job 2","Job 2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-06-28T00:00:00","2024-06-28T00:00:14","2024-06-28T00:00:32","2024-06-28T00:00:51","2024-06-28T00:01:27","2024-06-28T00:01:58","2024-06-28T00:02:20","2024-06-28T00:02:39","2024-06-28T00:03:11","2024-06-28T00:03:27"],"customdata":[[0],[0],[1],[1],[2],[2],[3],[3],[4],[4]],"hovertemplate":"Task=Machine 1\u003cbr\u003eStart=%{base}\u003cbr\u003eFinish=%{x}\u003cbr\u003eJob=%{y}\u003cbr\u003eIndex=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machine 1","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Machine 1","offsetgroup":"Machine 1","orientation":"h","showlegend":true,"textposition":"auto","x":[14000.0,18000.0,19000.0,36000.0,31000.0,22000.0,19000.0,32000.0,16000.0,12000.0],"xaxis":"x","y":["Job 3","Job 4","Job 3","Job 4","Job 3","Job 4","Job 3","Job 4","Job 3","Job 4"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...

# %% [markdown]
# # 7.모델 저장 후 재 학습

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model') # 저장 경로 및 파일명 지정
model.save(PPO_path)

# %%
model = PPO.load('PPO_model', env=env)

# %%
model.learn(total_timesteps=5000,tb_log_name='result',reset_num_timesteps=False)

# %% [markdown]
# #8. 다른 강화학습 알고리즘 사용

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)

# %%
model.learn(total_timesteps=100000)
